# %%
import pandas as pd

# %%
# Create a datarame
df = pd.read_csv(r"C:\Users\chibw\Documents\Portfolio\PortfolioProjects\RealEstate\kijijiRentalData2024-03-21_V1.csv")
df
# Out:
#                                                     url  \
# 0     https://www.kijiji.ca/v-apartments-condos/city...
# 1     https://www.kijiji.ca/v-apartments-condos/miss...
# 2     https://www.kijiji.ca/v-apartments-condos/miss...
# 3     https://www.kijiji.ca/v-apartments-condos/city...
# 4     https://www.kijiji.ca/v-apartments-condos/miss...
# ...                                                 ...
# 3612  https://www.kijiji.ca/v-apartments-condos/city...
# 3613  https://www.kijiji.ca/v-apartments-condos/city...
# 3614  https://www.kijiji.ca/v-apartments-condos/miss...
# 3615  https://www.kijiji.ca/v-apartments-condos/city...
# 3616  https://www.kijiji.ca/v-apartments-condos/miss...
#
#                                                   title  \
# 0     One bedroom, Steps to Finch subway, Utilities ...
# 1        Mississauga Square One 3 bedroom unit for rent
# 2                                                   NaN
# 3              Luxury Condo near Scarborough Town Cente
# 4     One bedroom basement available from 1st April ...
# ...                                                 ...
# 3612             Trinity Bellwoods - 2 Bedroom Basement
# 3613                 FURNISHED PRIVATE BEDROOM 1250 cad
# 3614  *Basement With Separate Entrance For Rent $149...
# 3615  Luxury 2-Bedroom at 222 The Esplanade, Front &...
# 3616  Brampton Village Townhomes - 2 Bdrm available ...
#
#                                           address                datePosted  \
# 0                    Olive Avenue, North York, ON  2024-03-21T04:44:14.000Z
# 1                         Mississauga, ON L5C 3M3  2024-03-21T04:31:20.000Z
# 2                                             NaN                       NaN
# 3              Lee Centre Dr, Scarborough, ON M1H  2024-03-21T04:14:21.000Z
# 4                             Mississauga, ON L4T  2024-03-21T04:02:03.000Z
# ...                                           ...                       ...
# 3612                          Toronto, ON M6J 1L5                       NaN
# 3613          640 Lauder Ave, Toronto, ON M6E 3K1                       NaN
# 3614  10 Wandering Trail Dr, Brampton, ON L7A 1T9                       NaN
# 3615   The Esplanade, Toronto, ON M5A 4M8, Canada                       NaN
# 3616       90 Orenda Court, Brampton, ON, L6W 3M9                       NaN
#
#        price propertyType           bedrooms     bathrooms  \
# 0     $2,500        Condo        Bedrooms: 1  Bathrooms: 1
# 1     $2,180        House        Bedrooms: 3  Bathrooms: 1
# 2        NaN          NaN                NaN           NaN
# 3     $2,500        Condo        Bedrooms: 2  Bathrooms: 1
# 4     $1,500     Basement        Bedrooms: 1  Bathrooms: 1
# ...      ...          ...                ...           ...
# 3612  $2,500     Basement        Bedrooms: 2  Bathrooms: 1
# 3613  $1,250    Apartment  Bedrooms: 1 + Den  Bathrooms: 1
# 3614  $1,495     Basement        Bedrooms: 1  Bathrooms: 1
# 3615  $2,800        Condo        Bedrooms: 2  Bathrooms: 1
# 3616  $2,540    Apartment        Bedrooms: 2  Bathrooms: 1
#
#                                             description  \
# 0     breathtaking unobstructed north-east views mee...
# 1     Walkable distance to Square One Mississauga, l...
# 2                                                   NaN
# 3     Luxury condo for rental : 2 bed and 1 washroom...
# 4     One bedroom spacious basement available in Mal...
# ...                                                 ...
# 3612  This Beautiful, Rarely Offered Stunning Victor...
# 3613  Hi there!\nI decide to give for rent fully fur...
# 3614  *Basement With Separate Entrance For Rent $149...
# 3615                Address: 222 The Esplanade, Toronto
# 3616                                                NaN
#
#                                               utilities parking  \
# 0     ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       1
# 1                                      ['Not Included']       1
# 2                                                    []     NaN
# 3                                      ['Not Included']       1
# 4                                      ['Not Included']       1
# ...                                                 ...     ...
# 3612                                   ['Not Included']       0
# 3613  ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       0
# 3614                                   ['Not Included']       2
# 3615  ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       0
# 3616                                                 []     NaN
#
#       aggreementType petFriendly   size furnished  \
# 0             1 Year     Limited  600.0        No
# 1             1 Year     Limited  900.0        No
# 2                NaN         NaN    NaN       NaN
# 3             1 Year     Limited  720.0        No
# 4     Month-to-month          No  800.0        No
# ...              ...         ...    ...       ...
# 3612          1 Year     Limited  650.0        No
# 3613  Month-to-month     Limited  800.0       Yes
# 3614          1 Year          No  800.0        No
# 3615          1 Year          No  600.0       Yes
# 3616             NaN         NaN    NaN       NaN
#
#                                              appliances  a/c outdoorSpace  \
# 0     ['Laundry (In Unit)', '', 'Dishwasher', 'Fridg...  Yes      Balcony
# 1     ['Laundry (In Unit)', '', 'Dishwasher', 'Fridg...  Yes          NaN
# 2                                                    []  NaN          NaN
# 3                                                    []  Yes          NaN
# 4                     ['Laundry (In Unit)', '', '', '']  Yes          NaN
# ...                                                 ...  ...          ...
# 3612  ['', 'Laundry (In Building)', '', 'Fridge / Fr...  Yes          NaN
# 3613                                                 []   No          NaN
# 3614                                                 []  Yes          NaN
# 3615  ['Laundry (In Unit)', 'Laundry (In Building)',...  Yes          NaN
# 3616                                                 []  NaN          NaN
#
#                                               amenities
# 0     ['Gym', '', 'Concierge', '24 Hour Security', '...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3612                                                 []
# 3613   ['', '', '', '', '', '', 'Elevator in Building']
# 3614                                                 []
# 3615  ['Gym', 'Pool', 'Concierge', '24 Hour Security...
# 3616                                                 []
#
# [3617 rows x 19 columns]

# %%
# Remove duplicates
df = df.drop_duplicates()
df
# Out:
#                                                     url  \
# 0     https://www.kijiji.ca/v-apartments-condos/city...
# 1     https://www.kijiji.ca/v-apartments-condos/miss...
# 2     https://www.kijiji.ca/v-apartments-condos/miss...
# 3     https://www.kijiji.ca/v-apartments-condos/city...
# 4     https://www.kijiji.ca/v-apartments-condos/miss...
# ...                                                 ...
# 3612  https://www.kijiji.ca/v-apartments-condos/city...
# 3613  https://www.kijiji.ca/v-apartments-condos/city...
# 3614  https://www.kijiji.ca/v-apartments-condos/miss...
# 3615  https://www.kijiji.ca/v-apartments-condos/city...
# 3616  https://www.kijiji.ca/v-apartments-condos/miss...
#
#                                                   title  \
# 0     One bedroom, Steps to Finch subway, Utilities ...
# 1        Mississauga Square One 3 bedroom unit for rent
# 2                                                   NaN
# 3              Luxury Condo near Scarborough Town Cente
# 4     One bedroom basement available from 1st April ...
# ...                                                 ...
# 3612             Trinity Bellwoods - 2 Bedroom Basement
# 3613                 FURNISHED PRIVATE BEDROOM 1250 cad
# 3614  *Basement With Separate Entrance For Rent $149...
# 3615  Luxury 2-Bedroom at 222 The Esplanade, Front &...
# 3616  Brampton Village Townhomes - 2 Bdrm available ...
#
#                                           address                datePosted  \
# 0                    Olive Avenue, North York, ON  2024-03-21T04:44:14.000Z
# 1                         Mississauga, ON L5C 3M3  2024-03-21T04:31:20.000Z
# 2                                             NaN                       NaN
# 3              Lee Centre Dr, Scarborough, ON M1H  2024-03-21T04:14:21.000Z
# 4                             Mississauga, ON L4T  2024-03-21T04:02:03.000Z
# ...                                           ...                       ...
# 3612                          Toronto, ON M6J 1L5                       NaN
# 3613          640 Lauder Ave, Toronto, ON M6E 3K1                       NaN
# 3614  10 Wandering Trail Dr, Brampton, ON L7A 1T9                       NaN
# 3615   The Esplanade, Toronto, ON M5A 4M8, Canada                       NaN
# 3616       90 Orenda Court, Brampton, ON, L6W 3M9                       NaN
#
#        price propertyType           bedrooms     bathrooms  \
# 0     $2,500        Condo        Bedrooms: 1  Bathrooms: 1
# 1     $2,180        House        Bedrooms: 3  Bathrooms: 1
# 2        NaN          NaN                NaN           NaN
# 3     $2,500        Condo        Bedrooms: 2  Bathrooms: 1
# 4     $1,500     Basement        Bedrooms: 1  Bathrooms: 1
# ...      ...          ...                ...           ...
# 3612  $2,500     Basement        Bedrooms: 2  Bathrooms: 1
# 3613  $1,250    Apartment  Bedrooms: 1 + Den  Bathrooms: 1
# 3614  $1,495     Basement        Bedrooms: 1  Bathrooms: 1
# 3615  $2,800        Condo        Bedrooms: 2  Bathrooms: 1
# 3616  $2,540    Apartment        Bedrooms: 2  Bathrooms: 1
#
#                                             description  \
# 0     breathtaking unobstructed north-east views mee...
# 1     Walkable distance to Square One Mississauga, l...
# 2                                                   NaN
# 3     Luxury condo for rental : 2 bed and 1 washroom...
# 4     One bedroom spacious basement available in Mal...
# ...                                                 ...
# 3612  This Beautiful, Rarely Offered Stunning Victor...
# 3613  Hi there!\nI decide to give for rent fully fur...
# 3614  *Basement With Separate Entrance For Rent $149...
# 3615                Address: 222 The Esplanade, Toronto
# 3616                                                NaN
#
#                                               utilities parking  \
# 0     ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       1
# 1                                      ['Not Included']       1
# 2                                                    []     NaN
# 3                                      ['Not Included']       1
# 4                                      ['Not Included']       1
# ...                                                 ...     ...
# 3612                                   ['Not Included']       0
# 3613  ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       0
# 3614                                   ['Not Included']       2
# 3615  ['Yes: Hydro', 'Yes: Heat', 'Yes: Water', 'Yes...       0
# 3616                                                 []     NaN
#
#       aggreementType petFriendly   size furnished  \
# 0             1 Year     Limited  600.0        No
# 1             1 Year     Limited  900.0        No
# 2                NaN         NaN    NaN       NaN
# 3             1 Year     Limited  720.0        No
# 4     Month-to-month          No  800.0        No
# ...              ...         ...    ...       ...
# 3612          1 Year     Limited  650.0        No
# 3613  Month-to-month     Limited  800.0       Yes
# 3614          1 Year          No  800.0        No
# 3615          1 Year          No  600.0       Yes
# 3616             NaN         NaN    NaN       NaN
#
#                                              appliances  a/c outdoorSpace  \
# 0     ['Laundry (In Unit)', '', 'Dishwasher', 'Fridg...  Yes      Balcony
# 1     ['Laundry (In Unit)', '', 'Dishwasher', 'Fridg...  Yes          NaN
# 2                                                    []  NaN          NaN
# 3                                                    []  Yes          NaN
# 4                     ['Laundry (In Unit)', '', '', '']  Yes          NaN
# ...                                                 ...  ...          ...
# 3612  ['', 'Laundry (In Building)', '', 'Fridge / Fr...  Yes          NaN
# 3613                                                 []   No          NaN
# 3614                                                 []  Yes          NaN
# 3615  ['Laundry (In Unit)', 'Laundry (In Building)',...  Yes          NaN
# 3616                                                 []  NaN          NaN
#
#                                               amenities
# 0     ['Gym', '', 'Concierge', '24 Hour Security', '...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3612                                                 []
# 3613   ['', '', '', '', '', '', 'Elevator in Building']
# 3614                                                 []
# 3615  ['Gym', 'Pool', 'Concierge', '24 Hour Security...
# 3616                                                 []
#
# [3616 rows x 19 columns]

# %%
# Find listings without prices and deleteall rows without prices
null_mask = df["price"].notnull()
print(f" length before: {len(df)}")
print(f" length after: {len(df[null_mask])}")
df=df[null_mask]
# Out:
#  length before: 3616
#  length after: 3520

# %%
# Check datatypes of the columns
len(df)
df.dtypes
# Out:
# url                object
# title              object
# address            object
# datePosted         object
# price              object
# propertyType       object
# bedrooms           object
# bathrooms          object
# description        object
# utilities          object
# parking            object
# aggreementType     object
# petFriendly        object
# size              float64
# furnished          object
# appliances         object
# a/c                object
# outdoorSpace       object
# amenities          object
# dtype: object

# %%
# Cleaning columns by removing brackets and quotation marks

pd.options.display.max_colwidth = 200
Bedrooms = []
Bathrooms = []
Price = []
Appliances = []
Amenities = []
Utilities = []

for index, row in df.iterrows():
    df.loc[index:index,'appliances'] =row['appliances'].strip('[]').replace("'", "")
    df.loc[index:index,'amenities'] =row['amenities'].strip('[]').replace("'", "")
    df.loc[index:index,'price'] =row['price'].split('$')[1].replace("'", "")
    df.loc[index:index,'utilities'] =row['utilities'].strip('[]').replace("'", "")
    df.loc[index:index,'bedrooms'] =row['bedrooms'].split(':' )[1].replace("'", "")
    df.loc[index:index,'bathrooms'] =row['bathrooms'].split(':')[1].replace("'", "")
    df.loc[index:index,'datePosted'] = pd.to_datetime(row['datePosted'])
# print(type(Bedrooms), type(Bathrooms), type(Price), type(Appliances), type(Amenities), type(Utilities))
# df.loc[df.bedrooms]=Bedrooms
# df.loc[df.bathrooms]=Bathrooms
# df.loc[df.price]=Price
# dfdf.loc[df.amenities]=Amenities
# df.loc[df.appliances]=Appliances
# df.loc[df.utilities]=Utilities

df
# Out:
#                                                                                                                                                url  \
# 0                        https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-steps-to-finch-subway-utilities-included/1688808011
# 1                      https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/mississauga-square-one-3-bedroom-unit-for-rent/1688807596
# 3                                    https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-condo-near-scarborough-town-cente/1688807077
# 4                  https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/one-bedroom-basement-available-from-1st-april-2024/1688806705
# 5     https://www.kijiji.ca/v-apartments-condos/oakville-halton-region/dundas-trafalgar-one-bed-branthaven-condo-avail-for-rent-april-1/1688806308
# ...                                                                                                                                            ...
# 3612                                     https://www.kijiji.ca/v-apartments-condos/city-of-toronto/trinity-bellwoods-2-bedroom-basement/1683055717
# 3613                                       https://www.kijiji.ca/v-apartments-condos/city-of-toronto/furnished-private-bedroom-1250-cad/1683043623
# 3614     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/basement-with-separate-entrance-for-rent-1495-with-2-parking/1683043495
# 3615                https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-2-bedroom-at-222-the-esplanade-front-amp-sherborne/1683033431
# 3616     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/brampton-village-townhomes-2-bdrm-available-at-75-85-90-oren/1673561156
#
#                                                                  title  \
# 0               One bedroom, Steps to Finch subway, Utilities included
# 1                       Mississauga Square One 3 bedroom unit for rent
# 3                             Luxury Condo near Scarborough Town Cente
# 4                  One bedroom basement available from 1st April 2024.
# 5     Dundas/Trafalgar One Bed Branthaven Condo Avail For Rent April 1
# ...                                                                ...
# 3612                            Trinity Bellwoods - 2 Bedroom Basement
# 3613                                FURNISHED PRIVATE BEDROOM 1250 cad
# 3614    *Basement With Separate Entrance For Rent $1495 With 2 Parking
# 3615      Luxury 2-Bedroom at 222 The Esplanade, Front &amp; Sherborne
# 3616  Brampton Village Townhomes - 2 Bdrm available at 75, 85, 90 Oren
#
#                                           address                 datePosted  \
# 0                    Olive Avenue, North York, ON  2024-03-21 04:44:14+00:00
# 1                         Mississauga, ON L5C 3M3  2024-03-21 04:31:20+00:00
# 3              Lee Centre Dr, Scarborough, ON M1H  2024-03-21 04:14:21+00:00
# 4                             Mississauga, ON L4T  2024-03-21 04:02:03+00:00
# 5                            Oakville, ON L6H 7W6  2024-03-21 03:50:13+00:00
# ...                                           ...                        ...
# 3612                          Toronto, ON M6J 1L5                        NaT
# 3613          640 Lauder Ave, Toronto, ON M6E 3K1                        NaT
# 3614  10 Wandering Trail Dr, Brampton, ON L7A 1T9                        NaT
# 3615   The Esplanade, Toronto, ON M5A 4M8, Canada                        NaT
# 3616       90 Orenda Court, Brampton, ON, L6W 3M9                        NaT
#
#       price propertyType  bedrooms bathrooms  \
# 0     2,500        Condo         1         1
# 1     2,180        House         3         1
# 3     2,500        Condo         2         1
# 4     1,500     Basement         1         1
# 5     2,075        Condo         1         1
# ...     ...          ...       ...       ...
# 3612  2,500     Basement         2         1
# 3613  1,250    Apartment   1 + Den         1
# 3614  1,495     Basement         1         1
# 3615  2,800        Condo         2         1
# 3616  2,540    Apartment         2         1
#
#                                                                                                                                                                                                   description  \
# 0     breathtaking unobstructed north-east views meet an abundance of sunlight. This move-in-ready home features an open-concept living space with laminated flooring, rare pot lights in the bedroom for ...
# 1     Walkable distance to Square One Mississauga, lots of shops, restaurants, groceries nearby. 3km from UTM and 1km from Erindale Go Train station, direct buses going to UTM and Erindale station. The ...
# 3     Luxury condo for rental : 2 bed and 1 washroom in PRIME LOCATION\nEnjoy top-tier amenities such as 24-hour security, a modern gym, billiards room, indoor pool, and ample visitor parking. Located n...
# 4                                   One bedroom spacious basement available in Malton from 1st April, 2024. It includes one parking and is very well ventilated. It’s closer to Westwood mall, banks, fresco.
# 5     Preferred Single $2075, Couple $2200 Brand New Never Lived In 1 Bedroom Condo unit an Upper West Side Condos. 600 square Feet. Very spacious open concept floorplan. Closed off Laundry Room. Ideal ...
# ...                                                                                                                                                                                                       ...
# 3612  This Beautiful, Rarely Offered Stunning Victorian Modern Home Is Newly Painted & Move In Ready. Brand New Kitchen and Appliances With Lots Of Storage, Large Open Living Space, Both Bedrooms w/Doub...
# 3613  Hi there!\nI decide to give for rent fully furnished privet bedroom in my apartment.\n8 February'24 move in day!\nONLY for 1 (one) person - specious and bright PRIVATE bedroom\n(bathroom and kitch...
# 3614  *Basement With Separate Entrance For Rent $1495 With 2 Parking Area wandering trail Brampton*\nBasement:\n- 1 Bedroom\n- 1 Full Washroom\n- Living Room/ Rec Room in Basement\n- Separate Kitchen\n-...
# 3615                                                                                                                                                                      Address: 222 The Esplanade, Toronto
# 3616                                                                                                                                                                                                      NaN
#
#                                           utilities parking  aggreementType  \
# 0     Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       1          1 Year
# 1                                      Not Included       1          1 Year
# 3                                      Not Included       1          1 Year
# 4                                      Not Included       1  Month-to-month
# 5                                      Not Included       1          1 Year
# ...                                             ...     ...             ...
# 3612                                   Not Included       0          1 Year
# 3613  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0  Month-to-month
# 3614                                   Not Included       2          1 Year
# 3615  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0          1 Year
# 3616                                                    NaN             NaN
#
#      petFriendly   size furnished  \
# 0        Limited  600.0        No
# 1        Limited  900.0        No
# 3        Limited  720.0        No
# 4             No  800.0        No
# 5        Limited  600.0        No
# ...          ...    ...       ...
# 3612     Limited  650.0        No
# 3613     Limited  800.0       Yes
# 3614          No  800.0        No
# 3615          No  600.0       Yes
# 3616         NaN    NaN       NaN
#
#                                                                   appliances  \
# 0                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 1                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 3
# 4                                                    Laundry (In Unit), , ,
# 5                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# ...                                                                      ...
# 3612                             , Laundry (In Building), , Fridge / Freezer
# 3613
# 3614
# 3615  Laundry (In Unit), Laundry (In Building), Dishwasher, Fridge / Freezer
# 3616
#
#       a/c outdoorSpace  \
# 0     Yes      Balcony
# 1     Yes          NaN
# 3     Yes          NaN
# 4     Yes          NaN
# 5     Yes      Balcony
# ...   ...          ...
# 3612  Yes          NaN
# 3613   No          NaN
# 3614  Yes          NaN
# 3615  Yes          NaN
# 3616  NaN          NaN
#
#                                                                                          amenities
# 0         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 1
# 3
# 4
# 5         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# ...                                                                                            ...
# 3612
# 3613                                                              , , , , , , Elevator in Building
# 3614
# 3615  Gym, Pool, Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 3616
#
# [3520 rows x 19 columns]

# %%
# Sperate address column into street, city and postal when available
# For future visualization and analization


street=[]
city=[]
pstalCode=[]
addCol=[]
i=0
for index, row in df.iterrows():
    i+=1
    flag=False
    
    addCol.append(row['address'])
    splitAdd = row['address'].replace(', Canada', '').split(',')
    
    if len(splitAdd) >= 4:
        flag=True
        
        if len(splitAdd[-1]) <= 7:
            if 'ON' in splitAdd[-1] or 'ontario' in splitAdd[-1].lower():
                pstalCode.append(splitAdd[-1].replace('ON','').replace('Ontario','').replace('ontario',''))
                city.append(splitAdd[-3])
                strt=' '.join(splitAdd[:-2])
                street.append(strt)
            elif 'ON' in splitAdd[-2] or 'ontario' in splitAdd[-2].lower():
                pstalCode.append(splitAdd[-1])
                city.append(splitAdd[-3])
                strt=' '.join(splitAdd[:-2])
                street.append(strt)
            else:
                pstalCode.append(splitAdd[-1])
                city.append(splitAdd[-3])
                street.append(splitAdd[:-2])
        elif 'ON' in splitAdd[-1] or 'ontario' in splitAdd[-1].lower():
            pstalCode.append(splitAdd[len(splitAdd)-1].replace('ON','').replace('Ontario','').replace('ontario',''))
            city.append(splitAdd[-2])
            street.append(' '.join(splitAdd[:-2]))
        else:
            pstalCode.append(splitAdd[3].replace('ON','').replace('Ontario','').replace('ontario',''))
            city.append(splitAdd[1])
            street.append(splitAdd[0])
    elif len(splitAdd) == 3:
        flag=True
        if 'ON' in splitAdd[2] or 'ontario' in splitAdd[2].lower():
            pstalCode.append(splitAdd[2].replace('ON','').replace('Ontario','').replace('ontario',''))
            city.append(splitAdd[1])
            street.append(splitAdd[0])
        elif 'ON' in splitAdd[1] or 'ontario' in splitAdd[1].lower():
            pstalCode.append(splitAdd[2].replace('ON','').replace('Ontario','').replace('ontario',''))
            city.append(splitAdd[0])
            street.append('')
        else:
            pstalCode.append(splitAdd[2])
            city.append(splitAdd[1])
            street.append(splitAdd[0])
    elif len(splitAdd) == 2:
        if 'ON' in splitAdd[1] or 'ontario' in splitAdd[1].lower():
            flag=True
            pstalCode.append(splitAdd[1].replace('ON','').replace('Ontario','').replace('ontario',''))
            city.append(splitAdd[0])
            street.append('')
        elif len(splitAdd[1]) <= 7:
            flag=True
            pstalCode.append(splitAdd[1])
            city.append(splitAdd[0])
            street.append('')
    elif len(splitAdd) == 1:
        if 'ON' in splitAdd or 'ontario' in splitAdd[0].lower():
            flag=True
            pstalCode.append(splitAdd.replace('ON','').replace('Ontario','').replace('ontario','').strip())
            city.append('')
            street.append('')
        elif len(splitAdd) <= 7:
            flag=True
            pstalCode.append(splitAdd)
            city.append('')
            street.append('')
    else:
        flag=True
        pstalCode.append('')
        city.append('')
        street.append('')
    if flag == False:
        pstalCode.append('')
        city.append('')
        street.append('')

        
df.insert(df.columns.get_loc('address')+1, 'street', street)
df.insert(df.columns.get_loc('address')+2, 'city', city)
df.insert(df.columns.get_loc('address')+3, 'postalCode', pstalCode)

df
# Out:
#                                                                                                                                                url  \
# 0                        https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-steps-to-finch-subway-utilities-included/1688808011
# 1                      https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/mississauga-square-one-3-bedroom-unit-for-rent/1688807596
# 3                                    https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-condo-near-scarborough-town-cente/1688807077
# 4                  https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/one-bedroom-basement-available-from-1st-april-2024/1688806705
# 5     https://www.kijiji.ca/v-apartments-condos/oakville-halton-region/dundas-trafalgar-one-bed-branthaven-condo-avail-for-rent-april-1/1688806308
# ...                                                                                                                                            ...
# 3612                                     https://www.kijiji.ca/v-apartments-condos/city-of-toronto/trinity-bellwoods-2-bedroom-basement/1683055717
# 3613                                       https://www.kijiji.ca/v-apartments-condos/city-of-toronto/furnished-private-bedroom-1250-cad/1683043623
# 3614     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/basement-with-separate-entrance-for-rent-1495-with-2-parking/1683043495
# 3615                https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-2-bedroom-at-222-the-esplanade-front-amp-sherborne/1683033431
# 3616     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/brampton-village-townhomes-2-bdrm-available-at-75-85-90-oren/1673561156
#
#                                                                  title  \
# 0               One bedroom, Steps to Finch subway, Utilities included
# 1                       Mississauga Square One 3 bedroom unit for rent
# 3                             Luxury Condo near Scarborough Town Cente
# 4                  One bedroom basement available from 1st April 2024.
# 5     Dundas/Trafalgar One Bed Branthaven Condo Avail For Rent April 1
# ...                                                                ...
# 3612                            Trinity Bellwoods - 2 Bedroom Basement
# 3613                                FURNISHED PRIVATE BEDROOM 1250 cad
# 3614    *Basement With Separate Entrance For Rent $1495 With 2 Parking
# 3615      Luxury 2-Bedroom at 222 The Esplanade, Front &amp; Sherborne
# 3616  Brampton Village Townhomes - 2 Bdrm available at 75, 85, 90 Oren
#
#                                           address                 street  \
# 0                    Olive Avenue, North York, ON           Olive Avenue
# 1                         Mississauga, ON L5C 3M3
# 3              Lee Centre Dr, Scarborough, ON M1H          Lee Centre Dr
# 4                             Mississauga, ON L4T
# 5                            Oakville, ON L6H 7W6
# ...                                           ...                    ...
# 3612                          Toronto, ON M6J 1L5
# 3613          640 Lauder Ave, Toronto, ON M6E 3K1         640 Lauder Ave
# 3614  10 Wandering Trail Dr, Brampton, ON L7A 1T9  10 Wandering Trail Dr
# 3615   The Esplanade, Toronto, ON M5A 4M8, Canada          The Esplanade
# 3616       90 Orenda Court, Brampton, ON, L6W 3M9        90 Orenda Court
#
#               city postalCode                 datePosted  price propertyType  \
# 0       North York             2024-03-21 04:44:14+00:00  2,500        Condo
# 1      Mississauga    L5C 3M3  2024-03-21 04:31:20+00:00  2,180        House
# 3      Scarborough        M1H  2024-03-21 04:14:21+00:00  2,500        Condo
# 4      Mississauga        L4T  2024-03-21 04:02:03+00:00  1,500     Basement
# 5         Oakville    L6H 7W6  2024-03-21 03:50:13+00:00  2,075        Condo
# ...            ...        ...                        ...    ...          ...
# 3612       Toronto    M6J 1L5                        NaT  2,500     Basement
# 3613       Toronto    M6E 3K1                        NaT  1,250    Apartment
# 3614      Brampton    L7A 1T9                        NaT  1,495     Basement
# 3615       Toronto    M5A 4M8                        NaT  2,800        Condo
# 3616      Brampton    L6W 3M9                        NaT  2,540    Apartment
#
#       bedrooms  ...                                      utilities parking  \
# 0            1  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       1
# 1            3  ...                                   Not Included       1
# 3            2  ...                                   Not Included       1
# 4            1  ...                                   Not Included       1
# 5            1  ...                                   Not Included       1
# ...        ...  ...                                            ...     ...
# 3612         2  ...                                   Not Included       0
# 3613   1 + Den  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0
# 3614         1  ...                                   Not Included       2
# 3615         2  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0
# 3616         2  ...                                                    NaN
#
#       aggreementType petFriendly   size furnished  \
# 0             1 Year     Limited  600.0        No
# 1             1 Year     Limited  900.0        No
# 3             1 Year     Limited  720.0        No
# 4     Month-to-month          No  800.0        No
# 5             1 Year     Limited  600.0        No
# ...              ...         ...    ...       ...
# 3612          1 Year     Limited  650.0        No
# 3613  Month-to-month     Limited  800.0       Yes
# 3614          1 Year          No  800.0        No
# 3615          1 Year          No  600.0       Yes
# 3616             NaN         NaN    NaN       NaN
#
#                                                                   appliances  \
# 0                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 1                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 3
# 4                                                    Laundry (In Unit), , ,
# 5                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# ...                                                                      ...
# 3612                             , Laundry (In Building), , Fridge / Freezer
# 3613
# 3614
# 3615  Laundry (In Unit), Laundry (In Building), Dishwasher, Fridge / Freezer
# 3616
#
#       a/c outdoorSpace  \
# 0     Yes      Balcony
# 1     Yes          NaN
# 3     Yes          NaN
# 4     Yes          NaN
# 5     Yes      Balcony
# ...   ...          ...
# 3612  Yes          NaN
# 3613   No          NaN
# 3614  Yes          NaN
# 3615  Yes          NaN
# 3616  NaN          NaN
#
#                                                                                          amenities
# 0         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 1
# 3
# 4
# 5         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# ...                                                                                            ...
# 3612
# 3613                                                              , , , , , , Elevator in Building
# 3614
# 3615  Gym, Pool, Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 3616
#
# [3520 rows x 22 columns]

# %%
df
# Out:
#                                                                                                                                                url  \
# 0                        https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-steps-to-finch-subway-utilities-included/1688808011
# 1                      https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/mississauga-square-one-3-bedroom-unit-for-rent/1688807596
# 3                                    https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-condo-near-scarborough-town-cente/1688807077
# 4                  https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/one-bedroom-basement-available-from-1st-april-2024/1688806705
# 5     https://www.kijiji.ca/v-apartments-condos/oakville-halton-region/dundas-trafalgar-one-bed-branthaven-condo-avail-for-rent-april-1/1688806308
# ...                                                                                                                                            ...
# 3612                                     https://www.kijiji.ca/v-apartments-condos/city-of-toronto/trinity-bellwoods-2-bedroom-basement/1683055717
# 3613                                       https://www.kijiji.ca/v-apartments-condos/city-of-toronto/furnished-private-bedroom-1250-cad/1683043623
# 3614     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/basement-with-separate-entrance-for-rent-1495-with-2-parking/1683043495
# 3615                https://www.kijiji.ca/v-apartments-condos/city-of-toronto/luxury-2-bedroom-at-222-the-esplanade-front-amp-sherborne/1683033431
# 3616     https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/brampton-village-townhomes-2-bdrm-available-at-75-85-90-oren/1673561156
#
#                                                                  title  \
# 0               One bedroom, Steps to Finch subway, Utilities included
# 1                       Mississauga Square One 3 bedroom unit for rent
# 3                             Luxury Condo near Scarborough Town Cente
# 4                  One bedroom basement available from 1st April 2024.
# 5     Dundas/Trafalgar One Bed Branthaven Condo Avail For Rent April 1
# ...                                                                ...
# 3612                            Trinity Bellwoods - 2 Bedroom Basement
# 3613                                FURNISHED PRIVATE BEDROOM 1250 cad
# 3614    *Basement With Separate Entrance For Rent $1495 With 2 Parking
# 3615      Luxury 2-Bedroom at 222 The Esplanade, Front &amp; Sherborne
# 3616  Brampton Village Townhomes - 2 Bdrm available at 75, 85, 90 Oren
#
#                                           address                 street  \
# 0                    Olive Avenue, North York, ON           Olive Avenue
# 1                         Mississauga, ON L5C 3M3
# 3              Lee Centre Dr, Scarborough, ON M1H          Lee Centre Dr
# 4                             Mississauga, ON L4T
# 5                            Oakville, ON L6H 7W6
# ...                                           ...                    ...
# 3612                          Toronto, ON M6J 1L5
# 3613          640 Lauder Ave, Toronto, ON M6E 3K1         640 Lauder Ave
# 3614  10 Wandering Trail Dr, Brampton, ON L7A 1T9  10 Wandering Trail Dr
# 3615   The Esplanade, Toronto, ON M5A 4M8, Canada          The Esplanade
# 3616       90 Orenda Court, Brampton, ON, L6W 3M9        90 Orenda Court
#
#               city postalCode                 datePosted  price propertyType  \
# 0       North York             2024-03-21 04:44:14+00:00  2,500        Condo
# 1      Mississauga    L5C 3M3  2024-03-21 04:31:20+00:00  2,180        House
# 3      Scarborough        M1H  2024-03-21 04:14:21+00:00  2,500        Condo
# 4      Mississauga        L4T  2024-03-21 04:02:03+00:00  1,500     Basement
# 5         Oakville    L6H 7W6  2024-03-21 03:50:13+00:00  2,075        Condo
# ...            ...        ...                        ...    ...          ...
# 3612       Toronto    M6J 1L5                        NaT  2,500     Basement
# 3613       Toronto    M6E 3K1                        NaT  1,250    Apartment
# 3614      Brampton    L7A 1T9                        NaT  1,495     Basement
# 3615       Toronto    M5A 4M8                        NaT  2,800        Condo
# 3616      Brampton    L6W 3M9                        NaT  2,540    Apartment
#
#       bedrooms  ...                                      utilities parking  \
# 0            1  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       1
# 1            3  ...                                   Not Included       1
# 3            2  ...                                   Not Included       1
# 4            1  ...                                   Not Included       1
# 5            1  ...                                   Not Included       1
# ...        ...  ...                                            ...     ...
# 3612         2  ...                                   Not Included       0
# 3613   1 + Den  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0
# 3614         1  ...                                   Not Included       2
# 3615         2  ...  Yes: Hydro, Yes: Heat, Yes: Water, Yes: Water       0
# 3616         2  ...                                                    NaN
#
#       aggreementType petFriendly   size furnished  \
# 0             1 Year     Limited  600.0        No
# 1             1 Year     Limited  900.0        No
# 3             1 Year     Limited  720.0        No
# 4     Month-to-month          No  800.0        No
# 5             1 Year     Limited  600.0        No
# ...              ...         ...    ...       ...
# 3612          1 Year     Limited  650.0        No
# 3613  Month-to-month     Limited  800.0       Yes
# 3614          1 Year          No  800.0        No
# 3615          1 Year          No  600.0       Yes
# 3616             NaN         NaN    NaN       NaN
#
#                                                                   appliances  \
# 0                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 1                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# 3
# 4                                                    Laundry (In Unit), , ,
# 5                          Laundry (In Unit), , Dishwasher, Fridge / Freezer
# ...                                                                      ...
# 3612                             , Laundry (In Building), , Fridge / Freezer
# 3613
# 3614
# 3615  Laundry (In Unit), Laundry (In Building), Dishwasher, Fridge / Freezer
# 3616
#
#       a/c outdoorSpace  \
# 0     Yes      Balcony
# 1     Yes          NaN
# 3     Yes          NaN
# 4     Yes          NaN
# 5     Yes      Balcony
# ...   ...          ...
# 3612  Yes          NaN
# 3613   No          NaN
# 3614  Yes          NaN
# 3615  Yes          NaN
# 3616  NaN          NaN
#
#                                                                                          amenities
# 0         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 1
# 3
# 4
# 5         Gym, , Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# ...                                                                                            ...
# 3612
# 3613                                                              , , , , , , Elevator in Building
# 3614
# 3615  Gym, Pool, Concierge, 24 Hour Security, Bicycle Parking, Storage Space, Elevator in Building
# 3616
#
# [3520 rows x 22 columns]

# %%
# save cleaned and changed dataframe to csv file for further analysis and visualisation

df.to_csv('cleanedData.csv', index= False)
